# %%
import pandas as pd, warnings; warnings.filterwarnings('ignore')

# %%
news1 = pd.read_csv("../Data/Crawling_Data/지하철혼잡_20240604_12시05분58초.csv")

news1.head()
# Out:
#                   date                               title  \
# 0  2024-06-03 11:42:49  4~5일 한·아프리카 정상회의…서울 지하철·버스 집중배차 연장
# 1  2024-06-04 03:05:56                   울산 트램, 교통 혼잡 대책은?
# 2  2024-05-31 11:49:07        1일 서울 도심 퀴어축제·반대 집회… 교통혼잡 예상
# 3  2024-05-23 06:30:02     이용객 가장 많은 서울 지하철역은 잠실…강남 제치고 1위
# 4  2024-06-01 09:43:09          오늘 서울 도심 곳곳 대규모 집회…교통혼잡 예상
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/003/001...
# 1  https://n.news.naver.com/mnews/article/020/000...
# 2  https://n.news.naver.com/mnews/article/366/000...
# 3  https://n.news.naver.com/mnews/article/001/001...
# 4  https://n.news.naver.com/mnews/article/422/000...
#
#                                              content
# 0  [\n지하철 1~7호선, 우이신설선 등 일 43회씩 총 86회 증회서울 버스 351...
# 1  [\n첫 주민공청회 기대-우려 교차태화강역∼신복교차로 32분 주파… 울산도시철도 허...
# 2  [\n\n\n\n\n지난해 7월 1일 오후 서울 중구 삼일대로 일대에서 '제24회 ...
# 3  [\n홍대입구·구로디지털단지·1호선 서울역·신림·삼성역 순 잠실 하루 15.5만명…...
# ...

# %%
news2 = pd.read_csv("../Data/Crawling_Data/서울지하철혼잡_20240604_12시11분11초.csv")

news2.head()
# Out:
#                   date                               title  \
# 0  2024-06-03 11:42:49  4~5일 한·아프리카 정상회의…서울 지하철·버스 집중배차 연장
# 1  2024-05-23 06:30:02     이용객 가장 많은 서울 지하철역은 잠실…강남 제치고 1위
# 2  2024-05-23 19:16:00           서울지하철 공실 상가 시민 서비스 공간 재탄생
# 3  2024-05-16 06:03:15   서울지하철 4호선 이어 7호선도 ‘의자 없는 열차’ 시범운행
# 4  2024-05-15 11:16:05    서울지하철 7호선, 16일부터 '의자 없는 열차' 시범운행
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/003/001...
# 1  https://n.news.naver.com/mnews/article/001/001...
# 2  https://n.news.naver.com/mnews/article/277/000...
# 3  https://n.news.naver.com/mnews/article/022/000...
# 4  https://n.news.naver.com/mnews/article/018/000...
#
#                                              content
# 0  [\n지하철 1~7호선, 우이신설선 등 일 43회씩 총 86회 증회서울 버스 351...
# 1  [\n홍대입구·구로디지털단지·1호선 서울역·신림·삼성역 순 잠실 하루 15.5만명…...
# 2  [\n지하철 공실 상가 시민 위한 공간으로 활용토록 공공기관 대상으로 적극적 상가 ...
# 3  [\n혼잡도 개선 위한 대책… 효과성 검증 나선다16일 출근시간대부터 서울지하철 7...
# ...

# %%
news3 = pd.read_csv("../Data/Crawling_Data/서울 지하철 혼잡도 AI로 측정_20240604_12시15분34초.csv")

news3.head()
# Out:
#                   date                                      title  \
# 0  2023-06-20 07:29:02  서울 지하철 혼잡도 AI로 측정한다…교통카드·하중센서 데이터로 정확도 실증
# 1  2023-05-10 11:21:30                  서울시 지하철 역사, AI로 혼잡도 측정 추진
# 2  2024-04-29 06:31:01                           [기고]콩나물시루 지하철의 꿈
# 3  2024-05-03 03:01:46         교차로 꼬리물기 감지한 AI, 빅데이터로 최적 신호주기 찾아내
# 4  2023-11-02 13:44:29    ‘혼잡률 200% 육박’ 서울지하철…AI가 ‘심각’ 판단하면 진입 통제
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/016/000...
# 1  https://n.news.naver.com/mnews/article/449/000...
# 2  https://n.news.naver.com/mnews/article/018/000...
# 3  https://n.news.naver.com/mnews/article/020/000...
# 4  https://n.news.naver.com/mnews/article/056/001...
#
#                                              content
# 0  [\nAI기반 혼잡도 실시간 평가 용역 발주혼잡도 정보 직원·고객과 공유 검토\n\...
# 1  [\n\n\n\n\n출처:뉴시스지하철 혼잡도에 대한 우려가 커지는 가운데 서울시가 ...
# 2  [\n박병섭 서울교통공사 안전관리본부장\n\n\n\n 서울지하철에 처음 푸쉬맨이 등...
# ...

# %%
news4 = pd.read_csv("../Data/Crawling_Data/서울지하철혼잡AI예측_20240604_14시33분35초.csv")

news4.head()
# Out:
#                   date                                    title  \
# 0  2023-11-02 12:01:07                    지하철역 승강장 혼잡도 실시간 예측한다
# 1  2023-11-02 13:44:29  ‘혼잡률 200% 육박’ 서울지하철…AI가 ‘심각’ 판단하면 진입 통제
# 2  2023-11-03 05:34:00         의자 없애고 혼잡도 실시간 분석…서울 '지옥철' 오명 벗나
# 3  2023-06-23 14:40:01          김혜지 서울시의원, 지하철역 혼잡도…다양한 개선대책 추진
# 4  2020-09-14 11:44:43           SKT "서울 지하철 1~8호선 혼잡도 미리 확인한다"
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/018/000...
# 1  https://n.news.naver.com/mnews/article/056/001...
# 2  https://n.news.naver.com/mnews/article/421/000...
# 3  https://n.news.naver.com/mnews/article/081/000...
# 4  https://n.news.naver.com/mnews/article/629/000...
#
#                                              content
# 0  [\n행안부, 'AI 기반 지하철 승강장 혼잡도 예측 모델' 개발서울지하철 2개 역...
# 1  [\n\n\n\n\n김포시민들이 서울로 출퇴근할 때 주로 이용하는 교통수단, 김포 ...
# 2  [\n승강장 혼잡도 AI 분석모델 장한평·군자역 시범적용'혼잡도 심각' 4·7호선 ...
# ...
